# %%
# Question 1:

num = int(input("Enter a Number:"))

if num <= 1:
    print(num, "is not a prime number")
else:
    is_prime = True

for i in range(2, num):
    if num % i == 0:
        is_prime = False
        break

if is_prime:
    print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# 7 is a prime number

# %%
#  Quesiton 2

import random

num1 = random.randint(1,20)
num2 = random.randint(1,20)

user_answer = int(input(f"what is the answer of the number? {num1} X {num2}: "))

correct_answer = num1*num2

if user_answer == correct_answer:
    print("Correct!!!!")
else:
    print(f"It's Wrong. The correc answer is: {correct_answer}")
# Out:
# Correct!!!!

# %%
# Question 3

for num in range(100, 201):
    if num % 2 != 0:
        square = num **2
        print(f"The square of {num} number is: {square}")
# Out:
# The square of 101 number is: 10201
# The square of 103 number is: 10609
# The square of 105 number is: 11025
# The square of 107 number is: 11449
# The square of 109 number is: 11881
# The square of 111 number is: 12321
# The square of 113 number is: 12769
# The square of 115 number is: 13225
# The square of 117 number is: 13689
# The square of 119 number is: 14161
# The square of 121 number is: 14641
# The square of 123 number is: 15129
# The square of 125 number is: 15625
# The square of 127 number is: 16129
# The square of 129 number is: 16641
# The square of 131 number is: 17161
# The square of 133 number is: 17689
# The square of 135 number is: 18225
# The square of 137 number is: 18769
# The square of 139 number is: 19321
# The square of 141 number is: 19881
# The square of 143 number is: 20449
# The square of 145 number is: 21025
# The square of 147 number is: 21609
# The square of 149 number is: 22201
# The square of 151 number is: 22801
# The square of 153 number is: 23409
# ...

# %%
# Question 4


input_text = "This is a sample text. This text will be used to demonstrate the word counter."

words = input_text.split()  

word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1  
    else:
        word_count[word] = 1   

for word, count in word_count.items():
    print(f"'{word}': {count}")
# Out:
# 'This': 2
# 'is': 1
# 'a': 1
# 'sample': 1
# 'text.': 1
# 'text': 1
# 'will': 1
# 'be': 1
# 'used': 1
# 'to': 1
# 'demonstrate': 1
# 'the': 1
# 'word': 1
# 'counter.': 1

# %%
# Question 5


def is_palindrome(s):
    clean_s = ''.join(char.lower() for char in s if char.isalnum())
    
    return clean_s == clean_s[::-1]

text1 = "madam"
text2 = "nitin"
text3 = "racecar"
text4 = "hello"

print(is_palindrome(text1))  
print(is_palindrome(text2))  
print(is_palindrome(text3))  
print(is_palindrome(text4))
# Out:
# True
# True
# True
# False
